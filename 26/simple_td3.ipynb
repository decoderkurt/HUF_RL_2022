# %% [markdown]
# <a href="https://colab.research.google.com/github/decoderkurt/HUF_RL_2022/blob/main/26/simple_td3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir TD3

# %%
# !pip install box2d-py
# !pip install gym[Box_2D]
# Out:
# Collecting box2d-py
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 5.0 MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Requirement already satisfied: gym[Box_2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# WARNING: gym 0.17.3 does not provide the extra 'box_2d'
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.19.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box_2D]) (0.16.0)

# %%
import numpy as np
import torch as T
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import os

class ReplayBuffer():
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.terminal_memory[index] = done
        self.reward_memory[index] = reward
        self.action_memory[index] = action

        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones


class CriticNetwork(nn.Module):
    def __init__(self, beta, input_dims, fc1_dims, fc2_dims, n_actions,
            name, chkpt_dir='TD3'):
        super(CriticNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_td3')

        self.fc1 = nn.Linear(self.input_dims[0] + n_actions, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.q1 = nn.Linear(self.fc2_dims, 1)

        self.optimizer = optim.Adam(self.parameters(), lr=beta)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')

        self.to(self.device)

    def forward(self, state, action):
        q1_action_value = self.fc1(T.cat([state, action], dim=1))
        q1_action_value = F.relu(q1_action_value)
        q1_action_value = self.fc2(q1_action_value)
        q1_action_value = F.relu(q1_action_value)

        q1 = self.q1(q1_action_value)

        return q1

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

class ActorNetwork(nn.Module):
    def __init__(self, alpha, input_dims, fc1_dims, fc2_dims,
            n_actions, name, chkpt_dir='TD3'):
        super(ActorNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_td3')

        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.mu = nn.Linear(self.fc2_dims, self.n_actions)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')

        self.to(self.device)

    def forward(self, state):
        prob = self.fc1(state)
        prob = F.relu(prob)
        prob = self.fc2(prob)
        prob = F.relu(prob)

        mu = T.tanh(self.mu(prob))

        return mu

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))


class Agent():
    def __init__(self, alpha, beta, input_dims, tau, env,
            gamma=0.99, update_actor_interval=2, warmup=1000,
            n_actions=2, max_size=1000000, layer1_size=400,
            layer2_size=300, batch_size=100, noise=0.1):
        self.gamma = gamma
        self.tau = tau
        self.max_action = env.action_space.high
        self.min_action = env.action_space.low
        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        self.batch_size = batch_size
        self.learn_step_cntr = 0
        self.time_step = 0
        self.warmup = warmup
        self.n_actions = n_actions
        self.update_actor_iter = update_actor_interval

        self.actor = ActorNetwork(alpha, input_dims, layer1_size,
                        layer2_size, n_actions=n_actions, name='actor')

        self.critic_1 = CriticNetwork(beta, input_dims, layer1_size,
                        layer2_size, n_actions=n_actions, name='critic_1')
        self.critic_2 = CriticNetwork(beta, input_dims, layer1_size,
                        layer2_size, n_actions=n_actions, name='critic_2')

        self.target_actor = ActorNetwork(alpha, input_dims, layer1_size,
                    layer2_size, n_actions=n_actions, name='target_actor')
        self.target_critic_1 = CriticNetwork(beta, input_dims, layer1_size,
                layer2_size, n_actions=n_actions, name='target_critic_1')
        self.target_critic_2 = CriticNetwork(beta, input_dims, layer1_size,
                layer2_size, n_actions=n_actions, name='target_critic_2')

        self.noise = noise
        self.update_network_parameters(tau=1)

    def choose_action(self, observation):
        if self.time_step < self.warmup:
            mu = T.tensor(np.random.normal(scale=self.noise, 
                                            size=(self.n_actions,)))
        else:
            state = T.tensor(observation, dtype=T.float).to(self.actor.device)
            mu = self.actor.forward(state).to(self.actor.device)
        mu_prime = mu + T.tensor(np.random.normal(scale=self.noise),
                                    dtype=T.float).to(self.actor.device)

        mu_prime = T.clamp(mu_prime, self.min_action[0], self.max_action[0])
        self.time_step += 1

        return mu_prime.cpu().detach().numpy()

    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return 
        state, action, reward, new_state, done = \
                self.memory.sample_buffer(self.batch_size)

        reward = T.tensor(reward, dtype=T.float).to(self.critic_1.device)
        done = T.tensor(done).to(self.critic_1.device)
        state_ = T.tensor(new_state, dtype=T.float).to(self.critic_1.device)
        state = T.tensor(state, dtype=T.float).to(self.critic_1.device)
        action = T.tensor(action, dtype=T.float).to(self.critic_1.device)
        
        target_actions = self.target_actor.forward(state_)
        target_actions = target_actions + \
                T.clamp(T.tensor(np.random.normal(scale=0.2)), -0.5, 0.5)
        target_actions = T.clamp(target_actions, self.min_action[0], 
                                self.max_action[0])
        
        q1_ = self.target_critic_1.forward(state_, target_actions)
        q2_ = self.target_critic_2.forward(state_, target_actions)

        q1 = self.critic_1.forward(state, action)
        q2 = self.critic_2.forward(state, action)

        q1_[done] = 0.0
        q2_[done] = 0.0

        q1_ = q1_.view(-1)
        q2_ = q2_.view(-1)

        critic_value_ = T.min(q1_, q2_)

        target = reward + self.gamma*critic_value_
        target = target.view(self.batch_size, 1)

        self.critic_1.optimizer.zero_grad()
        self.critic_2.optimizer.zero_grad()

        q1_loss = F.mse_loss(target, q1)
        q2_loss = F.mse_loss(target, q2)
        critic_loss = q1_loss + q2_loss
        critic_loss.backward()
        self.critic_1.optimizer.step()
        self.critic_2.optimizer.step()

        self.learn_step_cntr += 1

        if self.learn_step_cntr % self.update_actor_iter != 0:
            return

        self.actor.optimizer.zero_grad()
        actor_q1_loss = self.critic_1.forward(state, self.actor.forward(state))
        actor_loss = -T.mean(actor_q1_loss)
        actor_loss.backward()
        self.actor.optimizer.step()

        self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_1_params = self.critic_1.named_parameters()
        critic_2_params = self.critic_2.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_1_params = self.target_critic_1.named_parameters()
        target_critic_2_params = self.target_critic_2.named_parameters()

        critic_1 = dict(critic_1_params)
        critic_2 = dict(critic_2_params)
        actor = dict(actor_params)
        target_actor = dict(target_actor_params)
        target_critic_1 = dict(target_critic_1_params)
        target_critic_2 = dict(target_critic_2_params)

        for name in critic_1:
            critic_1[name] = tau*critic_1[name].clone() + \
                    (1-tau)*target_critic_1[name].clone()

        for name in critic_2:
            critic_2[name] = tau*critic_2[name].clone() + \
                    (1-tau)*target_critic_2[name].clone()

        for name in actor:
            actor[name] = tau*actor[name].clone() + \
                    (1-tau)*target_actor[name].clone()

        self.target_critic_1.load_state_dict(critic_1)
        self.target_critic_2.load_state_dict(critic_2)
        self.target_actor.load_state_dict(actor)

    def save_models(self):
        self.actor.save_checkpoint()
        self.target_actor.save_checkpoint()
        self.critic_1.save_checkpoint()
        self.critic_2.save_checkpoint()
        self.target_critic_1.save_checkpoint()
        self.target_critic_2.save_checkpoint()

    def load_models(self):
        self.actor.load_checkpoint()
        self.target_actor.load_checkpoint()
        self.critic_1.load_checkpoint()
        self.critic_2.load_checkpoint()
        self.target_critic_1.load_checkpoint()
        self.target_critic_2.load_checkpoint()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(x, scores, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg)
    plt.title('Running average of previous 100 scores')
    plt.savefig(figure_file)

# %%
import gym
import numpy as np

env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.001, beta=0.001,
        input_dims=env.observation_space.shape, tau=0.005,
        env=env, batch_size=100, layer1_size=400, layer2_size=300,
        n_actions=env.action_space.shape[0])
n_games = 1000
filename = 'TD3/' + 'LunarLanderContinuous_' + str(n_games) + '_games.png'

best_score = env.reward_range[0]
score_history = []

#agent.load_models()

for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        agent.remember(observation, action, reward, observation_, done)
        agent.learn()
        score += reward
        observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()

    print('episode ', i, 'score %.1f' % score,
            'average score %.1f' % avg_score)

x = [i+1 for i in range(n_games)]
plot_learning_curve(x, score_history, filename)
# Out:
# ... loading checkpoint ...
# ... loading checkpoint ...
# ... loading checkpoint ...
# ... loading checkpoint ...
# ... loading checkpoint ...
# ... loading checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  0 score -185.8 average score -185.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  1 score -86.9 average score -136.4
# episode  2 score -174.8 average score -149.2
# episode  3 score -152.9 average score -150.1
# episode  4 score -177.1 average score -155.5
# episode  5 score -69.3 average score -141.1
# episode  6 score -273.9 average score -160.1
# episode  7 score -133.9 average score -156.8
# episode  8 score -129.3 average score -153.8
# episode  9 score -150.1 average score -153.4
# episode  10 score -1083.8 average score -238.0
# episode  11 score -1320.8 average score -328.2
# episode  12 score -724.4 average score -358.7
# episode  13 score -943.3 average score -400.4
# episode  14 score -715.2 average score -421.4
# episode  15 score -743.9 average score -441.6
# episode  16 score -1001.3 average score -474.5
# episode  17 score -776.2 average score -491.3
# episode  18 score -776.0 average score -506.3
# episode  19 score -968.9 average score -529.4
# episode  20 score -1257.4 average score -564.1
# episode  21 score -837.4 average score -576.5
# episode  22 score -1114.5 average score -599.9
# episode  23 score -1571.6 average score -640.4
# episode  24 score -1253.9 average score -664.9
# episode  25 score -733.5 average score -667.5
# episode  26 score -824.3 average score -673.3
# episode  27 score -829.3 average score -678.9
# episode  28 score -1458.3 average score -705.8
# episode  29 score -1158.7 average score -720.9
# episode  30 score -842.0 average score -724.8
# episode  31 score -839.6 average score -728.4
# episode  32 score -808.0 average score -730.8
# episode  33 score -1301.8 average score -747.6
# episode  34 score -700.0 average score -746.2
# episode  35 score -856.2 average score -749.3
# episode  36 score -779.0 average score -750.1
# episode  37 score -1317.8 average score -765.0
# episode  38 score -1247.6 average score -777.4
# episode  39 score -1380.4 average score -792.5
# episode  40 score -866.1 average score -794.3
# episode  41 score -1468.4 average score -810.3
# episode  42 score -1230.0 average score -820.1
# episode  43 score -1222.6 average score -829.2
# episode  44 score -1259.4 average score -838.8
# episode  45 score -1631.9 average score -856.0
# episode  46 score -1266.5 average score -864.8
# episode  47 score -963.9 average score -866.8
# episode  48 score -1186.3 average score -873.3
# episode  49 score -822.7 average score -872.3
# episode  50 score -849.5 average score -871.9
# episode  51 score -740.7 average score -869.4
# episode  52 score -681.0 average score -865.8
# episode  53 score -1179.6 average score -871.6
# episode  54 score -1286.5 average score -879.2
# episode  55 score -764.5 average score -877.1
# episode  56 score -1837.3 average score -894.0
# episode  57 score -731.2 average score -891.2
# episode  58 score -2244.2 average score -914.1
# episode  59 score -797.6 average score -912.2
# episode  60 score -739.0 average score -909.3
# episode  61 score -800.7 average score -907.6
# episode  62 score -728.6 average score -904.7
# episode  63 score -437.4 average score -897.4
# episode  64 score -128.9 average score -885.6
# episode  65 score -141.8 average score -874.3
# episode  66 score -88.8 average score -862.6
# episode  67 score -85.6 average score -851.2
# episode  68 score -385.4 average score -844.4
# episode  69 score -98.9 average score -833.8
# episode  70 score -167.3 average score -824.4
# episode  71 score -343.2 average score -817.7
# episode  72 score -182.7 average score -809.0
# episode  73 score -272.0 average score -801.7
# episode  74 score -199.4 average score -793.7
# episode  75 score -228.0 average score -786.3
# episode  76 score -211.8 average score -778.8
# episode  77 score -192.8 average score -771.3
# episode  78 score -129.2 average score -763.2
# episode  79 score -298.5 average score -757.4
# episode  80 score -326.3 average score -752.0
# episode  81 score -170.8 average score -745.0
# episode  82 score -162.2 average score -737.9
# episode  83 score -188.4 average score -731.4
# episode  84 score -169.4 average score -724.8
# episode  85 score -73.8 average score -717.2
# episode  86 score -227.9 average score -711.6
# episode  87 score -177.6 average score -705.5
# episode  88 score -313.1 average score -701.1
# episode  89 score -243.1 average score -696.0
# episode  90 score -242.0 average score -691.0
# episode  91 score -26.0 average score -683.8
# episode  92 score -293.3 average score -679.6
# episode  93 score -394.4 average score -676.6
# episode  94 score -222.8 average score -671.8
# episode  95 score -37.9 average score -665.2
# episode  96 score -302.5 average score -661.4
# episode  97 score -68.1 average score -655.4
# episode  98 score -187.3 average score -650.7
# episode  99 score -268.0 average score -646.8
# episode  100 score -176.8 average score -646.7
# episode  101 score -237.8 average score -648.3
# episode  102 score -208.6 average score -648.6
# episode  103 score -93.7 average score -648.0
# episode  104 score -324.9 average score -649.5
# episode  105 score -178.4 average score -650.6
# episode  106 score -224.0 average score -650.1
# episode  107 score -314.1 average score -651.9
# episode  108 score -165.9 average score -652.2
# episode  109 score -209.5 average score -652.8
# episode  110 score -220.3 average score -644.2
# episode  111 score -283.7 average score -633.8
# episode  112 score -167.6 average score -628.3
# episode  113 score -217.0 average score -621.0
# episode  114 score -166.5 average score -615.5
# episode  115 score -63.1 average score -608.7
# episode  116 score -78.2 average score -599.5
# episode  117 score -92.4 average score -592.6
# episode  118 score -102.1 average score -585.9
# episode  119 score -149.2 average score -577.7
# episode  120 score -154.6 average score -566.7
# episode  121 score -133.3 average score -559.6
# episode  122 score -291.8 average score -551.4
# episode  123 score -185.7 average score -537.5
# episode  124 score -142.2 average score -526.4
# episode  125 score -183.9 average score -520.9
# episode  126 score -167.3 average score -514.4
# episode  127 score -164.3 average score -507.7
# episode  128 score -175.7 average score -494.9
# episode  129 score -179.3 average score -485.1
# episode  130 score -165.7 average score -478.3
# episode  131 score -216.2 average score -472.1
# episode  132 score -268.8 average score -466.7
# episode  133 score -240.1 average score -456.1
# episode  134 score -178.9 average score -450.9
# episode  135 score -186.2 average score -444.2
# episode  136 score -141.5 average score -437.8
# episode  137 score -197.4 average score -426.6
# episode  138 score -244.6 average score -416.6
# episode  139 score -171.3 average score -404.5
# episode  140 score -182.7 average score -397.6
# episode  141 score -212.9 average score -385.1
# episode  142 score -225.7 average score -375.0
# episode  143 score -224.5 average score -365.1
# episode  144 score -197.5 average score -354.4
# episode  145 score -141.0 average score -339.5
# episode  146 score -139.9 average score -328.3
# episode  147 score -109.5 average score -319.7
# episode  148 score -163.3 average score -309.5
# episode  149 score -143.5 average score -302.7
# episode  150 score -177.5 average score -296.0
# episode  151 score -197.1 average score -290.5
# episode  152 score -127.9 average score -285.0
# episode  153 score -199.2 average score -275.2
# episode  154 score -125.2 average score -263.6
# episode  155 score -138.1 average score -257.3
# episode  156 score -193.4 average score -240.9
# episode  157 score -138.1 average score -235.0
# episode  158 score 14.2 average score -212.4
# episode  159 score -189.1 average score -206.3
# episode  160 score -131.4 average score -200.2
# episode  161 score -98.5 average score -193.2
# episode  162 score -189.9 average score -187.8
# episode  163 score -145.4 average score -184.9
# episode  164 score -113.4 average score -184.7
# episode  165 score -168.1 average score -185.0
# episode  166 score -200.9 average score -186.1
# episode  167 score -127.4 average score -186.5
# episode  168 score -172.1 average score -184.4
# episode  169 score -68.8 average score -184.1
# episode  170 score -102.1 average score -183.4
# episode  171 score -92.4 average score -180.9
# episode  172 score -95.1 average score -180.1
# episode  173 score -162.2 average score -179.0
# episode  174 score -204.8 average score -179.0
# episode  175 score -72.0 average score -177.5
# episode  176 score -201.1 average score -177.3
# episode  177 score -118.2 average score -176.6
# episode  178 score -211.0 average score -177.4
# episode  179 score -220.5 average score -176.6
# episode  180 score -188.3 average score -175.3
# episode  181 score -148.6 average score -175.0
# episode  182 score -210.6 average score -175.5
# episode  183 score -124.8 average score -174.9
# episode  184 score -190.6 average score -175.1
# episode  185 score -215.9 average score -176.5
# episode  186 score -201.3 average score -176.3
# episode  187 score -211.0 average score -176.6
# episode  188 score -123.4 average score -174.7
# episode  189 score -197.2 average score -174.2
# episode  190 score -151.4 average score -173.3
# episode  191 score -95.8 average score -174.0
# episode  192 score -133.4 average score -172.4
# episode  193 score -86.6 average score -169.4
# episode  194 score -83.7 average score -168.0
# episode  195 score -162.1 average score -169.2
# episode  196 score -103.2 average score -167.2
# episode  197 score -157.0 average score -168.1
# episode  198 score -114.9 average score -167.4
# episode  199 score -114.7 average score -165.8
# episode  200 score -157.8 average score -165.6
# episode  201 score -186.9 average score -165.1
# episode  202 score -139.7 average score -164.5
# episode  203 score -170.5 average score -165.2
# episode  204 score -106.3 average score -163.0
# episode  205 score -135.1 average score -162.6
# episode  206 score -167.1 average score -162.0
# episode  207 score -130.8 average score -160.2
# episode  208 score -153.7 average score -160.1
# episode  209 score -156.1 average score -159.5
# episode  210 score -175.1 average score -159.1
# episode  211 score -177.1 average score -158.0
# episode  212 score -116.9 average score -157.5
# episode  213 score -69.1 average score -156.0
# episode  214 score -115.8 average score -155.5
# episode  215 score -168.4 average score -156.6
# episode  216 score -232.3 average score -158.1
# episode  217 score -142.1 average score -158.6
# episode  218 score -136.6 average score -159.0
# episode  219 score -221.2 average score -159.7
# episode  220 score -111.2 average score -159.3
# episode  221 score -110.6 average score -159.0
# episode  222 score -89.9 average score -157.0
# episode  223 score -118.0 average score -156.3
# episode  224 score -74.2 average score -155.7
# episode  225 score -77.0 average score -154.6
# episode  226 score -29.7 average score -153.2
# episode  227 score -89.0 average score -152.5
# episode  228 score -87.4 average score -151.6
# episode  229 score -70.6 average score -150.5
# episode  230 score -74.1 average score -149.6
# episode  231 score -303.9 average score -150.4
# episode  232 score -263.5 average score -150.4
# episode  233 score -108.4 average score -149.1
# episode  234 score -92.3 average score -148.2
# episode  235 score -127.2 average score -147.6
# episode  236 score -98.7 average score -147.2
# episode  237 score -536.8 average score -150.6
# episode  238 score -88.4 average score -149.0
# episode  239 score -152.8 average score -148.8
# episode  240 score -37.7 average score -147.4
# episode  241 score -95.3 average score -146.2
# episode  242 score -175.7 average score -145.7
# episode  243 score -98.8 average score -144.5
# episode  244 score -137.1 average score -143.8
# episode  245 score -318.1 average score -145.6
# episode  246 score -62.7 average score -144.8
# episode  247 score -108.0 average score -144.8
# episode  248 score -312.8 average score -146.3
# episode  249 score -333.0 average score -148.2
# episode  250 score -558.7 average score -152.0
# episode  251 score -260.1 average score -152.7
# episode  252 score -35.7 average score -151.7
# episode  253 score 4.4 average score -149.7
# episode  254 score -93.8 average score -149.4
# episode  255 score -53.8 average score -148.6
# episode  256 score -40.9 average score -147.0
# episode  257 score -17.4 average score -145.8
# episode  258 score -160.8 average score -147.6
# episode  259 score -82.2 average score -146.5
# episode  260 score -28.1 average score -145.5
# episode  261 score -95.3 average score -145.4
# episode  262 score -10.4 average score -143.6
# episode  263 score -252.8 average score -144.7
# episode  264 score -47.0 average score -144.0
# episode  265 score -68.2 average score -143.1
# episode  266 score -54.5 average score -141.6
# episode  267 score -199.1 average score -142.3
# episode  268 score -53.3 average score -141.1
# episode  269 score -88.6 average score -141.3
# episode  270 score -102.0 average score -141.3
# episode  271 score -29.7 average score -140.7
# episode  272 score -94.2 average score -140.7
# episode  273 score -40.3 average score -139.5
# episode  274 score -94.2 average score -138.4
# episode  275 score -97.1 average score -138.6
# episode  276 score -108.8 average score -137.7
# episode  277 score -366.5 average score -140.2
# episode  278 score -56.8 average score -138.6
# episode  279 score -33.3 average score -136.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  280 score -56.6 average score -135.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  281 score -14.0 average score -134.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  282 score -31.4 average score -132.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  283 score -38.4 average score -131.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  284 score -22.6 average score -129.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  285 score -85.8 average score -128.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  286 score -62.4 average score -127.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  287 score -70.9 average score -125.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  288 score -87.4 average score -125.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  289 score -76.5 average score -124.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  290 score -46.8 average score -123.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  291 score -75.1 average score -122.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  292 score -49.0 average score -122.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  293 score -38.8 average score -121.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  294 score -76.3 average score -121.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  295 score -84.9 average score -120.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  296 score -51.0 average score -120.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  297 score -34.2 average score -118.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  298 score -81.4 average score -118.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  299 score -71.0 average score -118.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  300 score -22.9 average score -116.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  301 score -33.9 average score -115.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  302 score -28.7 average score -114.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  303 score -52.1 average score -113.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  304 score -15.9 average score -112.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  305 score -55.9 average score -111.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  306 score -44.9 average score -110.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  307 score -12.6 average score -108.9
# episode  308 score -194.3 average score -109.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  309 score -11.9 average score -107.8
# episode  310 score -207.8 average score -108.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  311 score -83.1 average score -107.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  312 score -27.3 average score -106.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  313 score 20.4 average score -105.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  314 score -31.0 average score -104.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  315 score -50.3 average score -103.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  316 score -65.4 average score -101.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  317 score -86.8 average score -101.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  318 score -37.0 average score -100.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  319 score -80.5 average score -98.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  320 score -4.3 average score -97.7
# episode  321 score -128.2 average score -97.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  322 score -70.3 average score -97.7
# episode  323 score -190.3 average score -98.4
# episode  324 score -114.1 average score -98.8
# episode  325 score -126.0 average score -99.3
# episode  326 score -115.0 average score -100.2
# episode  327 score -120.2 average score -100.5
# episode  328 score -244.3 average score -102.0
# episode  329 score -111.1 average score -102.4
# episode  330 score -78.2 average score -102.5
# episode  331 score -100.4 average score -100.5
# episode  332 score -131.1 average score -99.1
# episode  333 score -112.2 average score -99.2
# episode  334 score -58.5 average score -98.8
# episode  335 score -75.8 average score -98.3
# episode  336 score -54.1 average score -97.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  337 score -91.2 average score -93.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  338 score -64.2 average score -93.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  339 score -82.6 average score -92.5
# episode  340 score -64.3 average score -92.7
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  341 score -64.3 average score -92.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  342 score -80.5 average score -91.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  343 score -88.5 average score -91.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  344 score -81.5 average score -90.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  345 score -91.7 average score -88.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  346 score 250.9 average score -85.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  347 score -52.9 average score -84.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  348 score -59.0 average score -82.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  349 score 276.6 average score -76.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  350 score -70.7 average score -71.3
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  351 score 153.9 average score -67.2
# episode  352 score -56.0 average score -67.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  353 score 91.6 average score -66.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  354 score -23.6 average score -65.8
# episode  355 score -77.6 average score -66.1
# episode  356 score -34.1 average score -66.0
# episode  357 score -40.7 average score -66.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  358 score -77.7 average score -65.4
# episode  359 score -108.1 average score -65.7
# episode  360 score -86.8 average score -66.3
# episode  361 score -49.9 average score -65.8
# episode  362 score -43.9 average score -66.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  363 score 7.2 average score -63.5
# episode  364 score -59.5 average score -63.7
# episode  365 score -66.9 average score -63.6
# episode  366 score -53.0 average score -63.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  367 score -76.3 average score -62.4
# episode  368 score -66.2 average score -62.5
# episode  369 score -76.9 average score -62.4
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  370 score -83.8 average score -62.2
# episode  371 score -76.9 average score -62.7
# episode  372 score -65.9 average score -62.4
# episode  373 score -91.0 average score -62.9
# episode  374 score -99.8 average score -63.0
# episode  375 score -56.3 average score -62.6
# episode  376 score -108.1 average score -62.6
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  377 score -87.3 average score -59.8
# episode  378 score -60.9 average score -59.8
# episode  379 score -82.4 average score -60.3
# episode  380 score -41.2 average score -60.2
# episode  381 score -220.0 average score -62.2
# episode  382 score -61.8 average score -62.5
# episode  383 score -43.1 average score -62.6
# episode  384 score -68.9 average score -63.0
# episode  385 score 4.8 average score -62.1
# episode  386 score -57.4 average score -62.1
# episode  387 score -11.4 average score -61.5
# episode  388 score -24.8 average score -60.9
# episode  389 score -70.7 average score -60.8
# episode  390 score -57.4 average score -60.9
# episode  391 score -48.9 average score -60.6
# episode  392 score -41.3 average score -60.6
# episode  393 score -63.0 average score -60.8
# episode  394 score -53.0 average score -60.6
# episode  395 score -50.3 average score -60.2
# episode  396 score -19.5 average score -59.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  397 score 147.5 average score -58.1
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  398 score -67.7 average score -58.0
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  399 score -34.4 average score -57.6
# episode  400 score -166.0 average score -59.0
# episode  401 score -28.4 average score -59.0
# episode  402 score -52.7 average score -59.2
# episode  403 score -125.4 average score -59.9
# episode  404 score -25.0 average score -60.0
# episode  405 score -80.3 average score -60.3
# episode  406 score 105.9 average score -58.8
# episode  407 score -36.8 average score -59.0
# episode  408 score -55.2 average score -57.6
# episode  409 score -26.7 average score -57.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  410 score 178.6 average score -53.9
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  411 score -43.8 average score -53.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  412 score 150.6 average score -51.7
# episode  413 score -44.5 average score -52.4
# episode  414 score -44.5 average score -52.5
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  415 score 117.8 average score -50.8
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  416 score -2.9 average score -50.2
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  417 score -24.5 average score -49.6
