# %% [markdown]
# <a href="https://colab.research.google.com/github/decoderkurt/HUF_RL_2022/blob/main/25/simple_ddpg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir DDPG

# %%
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class OUActionNoise(object):
    def __init__(self, mu, sigma=0.15, theta=.2, dt=1e-2, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
            self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(
                                                            self.mu, self.sigma)

class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1 - done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

class CriticNetwork(nn.Module):
    def __init__(self, beta, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir='DDPG'):
        super(CriticNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        T.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
        T.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
        #self.fc1.weight.data.uniform_(-f1, f1)
        #self.fc1.bias.data.uniform_(-f1, f1)
        self.bn1 = nn.LayerNorm(self.fc1_dims)

        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        #f2 = 0.002
        T.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
        T.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
        #self.fc2.weight.data.uniform_(-f2, f2)
        #self.fc2.bias.data.uniform_(-f2, f2)
        self.bn2 = nn.LayerNorm(self.fc2_dims)

        self.action_value = nn.Linear(self.n_actions, self.fc2_dims)
        f3 = 0.003
        self.q = nn.Linear(self.fc2_dims, 1)
        T.nn.init.uniform_(self.q.weight.data, -f3, f3)
        T.nn.init.uniform_(self.q.bias.data, -f3, f3)
        #self.q.weight.data.uniform_(-f3, f3)
        #self.q.bias.data.uniform_(-f3, f3)

        self.optimizer = optim.Adam(self.parameters(), lr=beta)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state, action):
        state_value = self.fc1(state)
        state_value = self.bn1(state_value)
        state_value = F.relu(state_value)
        state_value = self.fc2(state_value)
        state_value = self.bn2(state_value)

        action_value = F.relu(self.action_value(action))
        state_action_value = F.relu(T.add(state_value, action_value))
        state_action_value = self.q(state_action_value)

        return state_action_value

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

class ActorNetwork(nn.Module):
    def __init__(self, alpha, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir='DDPG'):
        super(ActorNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        T.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
        T.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
        #self.fc1.weight.data.uniform_(-f1, f1)
        #self.fc1.bias.data.uniform_(-f1, f1)
        self.bn1 = nn.LayerNorm(self.fc1_dims)

        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        #f2 = 0.002
        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        T.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
        T.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
        #self.fc2.weight.data.uniform_(-f2, f2)
        #self.fc2.bias.data.uniform_(-f2, f2)
        self.bn2 = nn.LayerNorm(self.fc2_dims)

        #f3 = 0.004
        f3 = 0.003
        self.mu = nn.Linear(self.fc2_dims, self.n_actions)
        T.nn.init.uniform_(self.mu.weight.data, -f3, f3)
        T.nn.init.uniform_(self.mu.bias.data, -f3, f3)
        #self.mu.weight.data.uniform_(-f3, f3)
        #self.mu.bias.data.uniform_(-f3, f3)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state):
        x = self.fc1(state)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = T.tanh(self.mu(x))

        return x

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

class Agent(object):
    def __init__(self, alpha, beta, input_dims, tau, env, gamma=0.99,
                 n_actions=2, max_size=1000000, layer1_size=400,
                 layer2_size=300, batch_size=64):
        self.gamma = gamma
        self.tau = tau
        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        self.batch_size = batch_size

        self.actor = ActorNetwork(alpha, input_dims, layer1_size,
                                  layer2_size, n_actions=n_actions,
                                  name='Actor')
        self.critic = CriticNetwork(beta, input_dims, layer1_size,
                                    layer2_size, n_actions=n_actions,
                                    name='Critic')

        self.target_actor = ActorNetwork(alpha, input_dims, layer1_size,
                                         layer2_size, n_actions=n_actions,
                                         name='TargetActor')
        self.target_critic = CriticNetwork(beta, input_dims, layer1_size,
                                           layer2_size, n_actions=n_actions,
                                           name='TargetCritic')

        self.noise = OUActionNoise(mu=np.zeros(n_actions))

        self.update_network_parameters(tau=1)

    def choose_action(self, observation):
        self.actor.eval()
        observation = T.tensor(observation, dtype=T.float).to(self.actor.device)
        mu = self.actor.forward(observation).to(self.actor.device)
        mu_prime = mu + T.tensor(self.noise(),
                                 dtype=T.float).to(self.actor.device)
        self.actor.train()
        return mu_prime.cpu().detach().numpy()


    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return
        state, action, reward, new_state, done = \
                                      self.memory.sample_buffer(self.batch_size)

        reward = T.tensor(reward, dtype=T.float).to(self.critic.device)
        done = T.tensor(done).to(self.critic.device)
        new_state = T.tensor(new_state, dtype=T.float).to(self.critic.device)
        action = T.tensor(action, dtype=T.float).to(self.critic.device)
        state = T.tensor(state, dtype=T.float).to(self.critic.device)

        self.target_actor.eval()
        self.target_critic.eval()
        self.critic.eval()
        target_actions = self.target_actor.forward(new_state)
        critic_value_ = self.target_critic.forward(new_state, target_actions)
        critic_value = self.critic.forward(state, action)

        target = []
        for j in range(self.batch_size):
            target.append(reward[j] + self.gamma*critic_value_[j]*done[j])
        target = T.tensor(target).to(self.critic.device)
        target = target.view(self.batch_size, 1)

        self.critic.train()
        self.critic.optimizer.zero_grad()
        critic_loss = F.mse_loss(target, critic_value)
        critic_loss.backward()
        self.critic.optimizer.step()

        self.critic.eval()
        self.actor.optimizer.zero_grad()
        mu = self.actor.forward(state)
        self.actor.train()
        actor_loss = -self.critic.forward(state, mu)
        actor_loss = T.mean(actor_loss)
        actor_loss.backward()
        self.actor.optimizer.step()

        self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_params = self.critic.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(critic_params)
        actor_state_dict = dict(actor_params)
        target_critic_dict = dict(target_critic_params)
        target_actor_dict = dict(target_actor_params)

        for name in critic_state_dict:
            critic_state_dict[name] = tau*critic_state_dict[name].clone() + \
                                      (1-tau)*target_critic_dict[name].clone()

        self.target_critic.load_state_dict(critic_state_dict)

        for name in actor_state_dict:
            actor_state_dict[name] = tau*actor_state_dict[name].clone() + \
                                      (1-tau)*target_actor_dict[name].clone()
        self.target_actor.load_state_dict(actor_state_dict)

        """
        #Verify that the copy assignment worked correctly
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(target_critic_params)
        actor_state_dict = dict(target_actor_params)
        print('\nActor Networks', tau)
        for name, param in self.actor.named_parameters():
            print(name, T.equal(param, actor_state_dict[name]))
        print('\nCritic Networks', tau)
        for name, param in self.critic.named_parameters():
            print(name, T.equal(param, critic_state_dict[name]))
        input()
        """
    def save_models(self):
        self.actor.save_checkpoint()
        self.target_actor.save_checkpoint()
        self.critic.save_checkpoint()
        self.target_critic.save_checkpoint()

    def load_models(self):
        self.actor.load_checkpoint()
        self.target_actor.load_checkpoint()
        self.critic.load_checkpoint()
        self.target_critic.load_checkpoint()

    def check_actor_params(self):
        current_actor_params = self.actor.named_parameters()
        current_actor_dict = dict(current_actor_params)
        original_actor_dict = dict(self.original_actor.named_parameters())
        original_critic_dict = dict(self.original_critic.named_parameters())
        current_critic_params = self.critic.named_parameters()
        current_critic_dict = dict(current_critic_params)
        print('Checking Actor parameters')

        for param in current_actor_dict:
            print(param, T.equal(original_actor_dict[param], current_actor_dict[param]))
        print('Checking critic parameters')
        for param in current_critic_dict:
            print(param, T.equal(original_critic_dict[param], current_critic_dict[param]))
        input()

# %%
import matplotlib.pyplot as plt 
import numpy as np

def plotLearning(scores, filename, x=None, window=5):   
    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-window):(t+1)])
    if x is None:
        x = [i for i in range(N)]
    plt.ylabel('Score')       
    plt.xlabel('Game')                     
    plt.plot(x, running_avg)
    plt.savefig(filename)

# %%
# !pip install box2d-py
# !pip install gym[Box_2D]
# Out:
# Collecting box2d-py
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 5.3 MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Requirement already satisfied: gym[Box_2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# WARNING: gym 0.17.3 does not provide the extra 'box_2d'
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box_2D]) (0.16.0)

# %%
import gym
import numpy as np

env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.000025, beta=0.00025, input_dims=[8], tau=0.001, env=env,
              batch_size=64,  layer1_size=400, layer2_size=300, n_actions=2)

#agent.load_models()
np.random.seed(0)

score_history = []
for i in range(1000):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        act = agent.choose_action(obs)
        new_state, reward, done, info = env.step(act)
        agent.remember(obs, act, reward, new_state, int(done))
        agent.learn()
        score += reward
        obs = new_state
        #env.render()
    score_history.append(score)

    #if i % 25 == 0:
    #    agent.save_models()

    print('episode ', i, 'score %.2f' % score,
          'trailing 100 games avg %.3f' % np.mean(score_history[-100:]))

filename = 'LunarLander-alpha000025-beta00025-400-300.png'
plotLearning(score_history, filename, window=100)
# Out:
# episode  0 score -236.99 trailing 100 games avg -236.986
# episode  1 score -563.07 trailing 100 games avg -400.026
# episode  2 score -325.17 trailing 100 games avg -375.073
# episode  3 score -883.84 trailing 100 games avg -502.266
# episode  4 score -728.55 trailing 100 games avg -547.524
# episode  5 score -715.15 trailing 100 games avg -575.462
# episode  6 score -411.66 trailing 100 games avg -552.061
# episode  7 score -441.70 trailing 100 games avg -538.266
# episode  8 score -399.27 trailing 100 games avg -522.822
# episode  9 score -252.27 trailing 100 games avg -495.767
# episode  10 score -303.90 trailing 100 games avg -478.324
# episode  11 score -506.65 trailing 100 games avg -480.685
# episode  12 score -399.91 trailing 100 games avg -474.472
# episode  13 score -330.94 trailing 100 games avg -464.220
# episode  14 score -452.88 trailing 100 games avg -463.464
# episode  15 score -485.85 trailing 100 games avg -464.863
# episode  16 score -414.57 trailing 100 games avg -461.905
# episode  17 score -570.09 trailing 100 games avg -467.916
# episode  18 score -549.82 trailing 100 games avg -472.226
# episode  19 score -456.31 trailing 100 games avg -471.430
# episode  20 score -592.26 trailing 100 games avg -477.184
# episode  21 score -508.17 trailing 100 games avg -478.593
# episode  22 score -785.16 trailing 100 games avg -491.922
# episode  23 score -554.72 trailing 100 games avg -494.538
# episode  24 score -485.41 trailing 100 games avg -494.173
# episode  25 score -602.62 trailing 100 games avg -498.344
# episode  26 score -578.43 trailing 100 games avg -501.310
# episode  27 score -1120.74 trailing 100 games avg -523.433
# episode  28 score -395.89 trailing 100 games avg -519.035
# episode  29 score -490.29 trailing 100 games avg -518.077
# episode  30 score -827.61 trailing 100 games avg -528.062
# episode  31 score -338.00 trailing 100 games avg -522.122
# episode  32 score -290.37 trailing 100 games avg -515.099
# episode  33 score -427.38 trailing 100 games avg -512.519
# episode  34 score -280.54 trailing 100 games avg -505.891
# episode  35 score -437.10 trailing 100 games avg -503.981
# episode  36 score -382.16 trailing 100 games avg -500.688
# episode  37 score -312.05 trailing 100 games avg -495.724
# episode  38 score -348.73 trailing 100 games avg -491.955
# episode  39 score -272.18 trailing 100 games avg -486.460
# episode  40 score -279.15 trailing 100 games avg -481.404
# episode  41 score -342.49 trailing 100 games avg -478.097
# episode  42 score -379.70 trailing 100 games avg -475.808
# episode  43 score -375.25 trailing 100 games avg -473.523
# episode  44 score -272.21 trailing 100 games avg -469.049
# episode  45 score -179.21 trailing 100 games avg -462.748
# episode  46 score -243.96 trailing 100 games avg -458.093
# episode  47 score -252.96 trailing 100 games avg -453.819
# episode  48 score -319.91 trailing 100 games avg -451.087
# episode  49 score -305.76 trailing 100 games avg -448.180
# episode  50 score -321.86 trailing 100 games avg -445.703
# episode  51 score -364.48 trailing 100 games avg -444.141
# episode  52 score -276.51 trailing 100 games avg -440.978
# episode  53 score -268.51 trailing 100 games avg -437.785
# episode  54 score -294.18 trailing 100 games avg -435.174
# episode  55 score -320.26 trailing 100 games avg -433.122
# episode  56 score -324.17 trailing 100 games avg -431.210
# episode  57 score -235.04 trailing 100 games avg -427.828
# episode  58 score -208.73 trailing 100 games avg -424.114
# episode  59 score -243.36 trailing 100 games avg -421.102
# episode  60 score -314.92 trailing 100 games avg -419.361
# episode  61 score -195.43 trailing 100 games avg -415.749
# episode  62 score -126.41 trailing 100 games avg -411.157
# episode  63 score -108.71 trailing 100 games avg -406.431
# episode  64 score -308.41 trailing 100 games avg -404.923
# episode  65 score -345.60 trailing 100 games avg -404.024
# episode  66 score -293.26 trailing 100 games avg -402.371
# episode  67 score -211.97 trailing 100 games avg -399.571
# episode  68 score -59.92 trailing 100 games avg -394.648
# episode  69 score -314.20 trailing 100 games avg -393.499
# episode  70 score -123.33 trailing 100 games avg -389.694
# episode  71 score -256.30 trailing 100 games avg -387.841
# episode  72 score -89.49 trailing 100 games avg -383.754
# episode  73 score -263.17 trailing 100 games avg -382.125
# episode  74 score -228.81 trailing 100 games avg -380.081
# episode  75 score -96.25 trailing 100 games avg -376.346
# episode  76 score -93.78 trailing 100 games avg -372.676
# episode  77 score -169.04 trailing 100 games avg -370.066
# episode  78 score -11.37 trailing 100 games avg -365.525
# episode  79 score -112.72 trailing 100 games avg -362.365
# episode  80 score -249.15 trailing 100 games avg -360.967
# episode  81 score -133.43 trailing 100 games avg -358.193
# episode  82 score -237.16 trailing 100 games avg -356.734
# episode  83 score -144.79 trailing 100 games avg -354.211
# episode  84 score -197.09 trailing 100 games avg -352.363
# episode  85 score -285.41 trailing 100 games avg -351.584
# episode  86 score -162.59 trailing 100 games avg -349.412
# episode  87 score -274.88 trailing 100 games avg -348.565
# episode  88 score -240.81 trailing 100 games avg -347.354
# episode  89 score -196.71 trailing 100 games avg -345.680
# episode  90 score -188.47 trailing 100 games avg -343.953
# episode  91 score -139.31 trailing 100 games avg -341.728
# episode  92 score -102.30 trailing 100 games avg -339.154
# episode  93 score -216.95 trailing 100 games avg -337.854
# episode  94 score -242.78 trailing 100 games avg -336.853
# episode  95 score -241.68 trailing 100 games avg -335.862
# episode  96 score -119.37 trailing 100 games avg -333.630
# episode  97 score -288.78 trailing 100 games avg -333.172
# episode  98 score -209.82 trailing 100 games avg -331.926
# episode  99 score -233.76 trailing 100 games avg -330.945
# episode  100 score -102.73 trailing 100 games avg -329.602
# episode  101 score -41.71 trailing 100 games avg -324.388
# episode  102 score -243.07 trailing 100 games avg -323.567
# episode  103 score -198.39 trailing 100 games avg -316.713
# episode  104 score -192.48 trailing 100 games avg -311.352
# episode  105 score -203.24 trailing 100 games avg -306.233
# episode  106 score -276.39 trailing 100 games avg -304.880
# episode  107 score -263.55 trailing 100 games avg -303.099
# episode  108 score -56.90 trailing 100 games avg -299.675
# episode  109 score -247.50 trailing 100 games avg -299.627
# episode  110 score -36.30 trailing 100 games avg -296.952
# episode  111 score -261.55 trailing 100 games avg -294.500
# episode  228 score -211.78 trailing 100 games avg -186.519
# episode  229 score -121.02 trailing 100 games avg -184.946
# episode  230 score -196.70 trailing 100 games avg -181.790
# episode  231 score 182.28 trailing 100 games avg -178.063
# episode  232 score -226.16 trailing 100 games avg -179.035
# episode  233 score -110.39 trailing 100 games avg -175.730
# episode  234 score -315.56 trailing 100 games avg -177.740
# episode  235 score -160.63 trailing 100 games avg -175.614
# episode  236 score -269.95 trailing 100 games avg -174.975
# episode  237 score -192.17 trailing 100 games avg -173.921
# episode  238 score -179.95 trailing 100 games avg -171.476
# episode  239 score -285.98 trailing 100 games avg -172.232
# episode  240 score -266.20 trailing 100 games avg -173.535
# episode  241 score -234.15 trailing 100 games avg -174.210
# episode  242 score -217.06 trailing 100 games avg -174.316
# episode  243 score -245.56 trailing 100 games avg -174.925
# episode  244 score -197.09 trailing 100 games avg -175.167
# episode  245 score -213.59 trailing 100 games avg -175.167
# episode  246 score -195.39 trailing 100 games avg -174.293
# episode  247 score -302.62 trailing 100 games avg -175.514
# episode  248 score -214.18 trailing 100 games avg -175.844
# episode  249 score -176.35 trailing 100 games avg -177.436
# episode  250 score -162.26 trailing 100 games avg -177.285
# episode  251 score -163.99 trailing 100 games avg -177.101
# episode  252 score -179.15 trailing 100 games avg -177.966
# episode  253 score -188.08 trailing 100 games avg -177.941
# episode  254 score -251.96 trailing 100 games avg -177.265
# episode  255 score -168.95 trailing 100 games avg -178.882
# episode  256 score -152.64 trailing 100 games avg -178.482
# episode  257 score -107.33 trailing 100 games avg -179.832
# episode  258 score -143.31 trailing 100 games avg -181.161
# episode  259 score -113.51 trailing 100 games avg -180.228
# episode  260 score -140.12 trailing 100 games avg -180.492
# episode  261 score -463.96 trailing 100 games avg -183.894
# episode  262 score -241.52 trailing 100 games avg -184.842
# episode  263 score -328.81 trailing 100 games avg -185.713
# episode  264 score -144.37 trailing 100 games avg -183.372
# episode  265 score -145.33 trailing 100 games avg -183.499
# episode  266 score -131.19 trailing 100 games avg -183.254
# episode  267 score -158.28 trailing 100 games avg -184.048
# episode  268 score -133.75 trailing 100 games avg -184.310
# episode  269 score -199.41 trailing 100 games avg -184.308
# episode  270 score -293.25 trailing 100 games avg -185.427
# episode  271 score -191.39 trailing 100 games avg -186.531
# episode  272 score -176.35 trailing 100 games avg -187.154
# episode  273 score -237.49 trailing 100 games avg -188.301
# episode  274 score -307.14 trailing 100 games avg -188.481
# episode  275 score -198.39 trailing 100 games avg -189.293
# episode  276 score -173.26 trailing 100 games avg -188.936
# episode  277 score -261.96 trailing 100 games avg -189.662
# episode  278 score -162.26 trailing 100 games avg -189.489
# episode  279 score -240.07 trailing 100 games avg -190.248
# episode  280 score -233.86 trailing 100 games avg -191.692
# episode  281 score -181.11 trailing 100 games avg -191.069
# episode  282 score -194.77 trailing 100 games avg -190.845
# episode  283 score -50.39 trailing 100 games avg -189.992
# episode  284 score 31.67 trailing 100 games avg -187.632
# episode  285 score -193.53 trailing 100 games avg -188.602
# episode  286 score -240.35 trailing 100 games avg -189.214
# episode  345 score -62.27 trailing 100 games avg -171.717
# episode  346 score -115.68 trailing 100 games avg -170.919
# episode  347 score -35.89 trailing 100 games avg -168.252
# episode  348 score -10.54 trailing 100 games avg -166.216
# episode  349 score -50.37 trailing 100 games avg -164.956
# episode  350 score -180.10 trailing 100 games avg -165.134
# episode  351 score -57.80 trailing 100 games avg -164.072
# episode  352 score -13.23 trailing 100 games avg -162.413
# episode  353 score -13.89 trailing 100 games avg -160.671
# episode  354 score -72.13 trailing 100 games avg -158.873
# episode  355 score -86.03 trailing 100 games avg -158.044
# episode  356 score -49.39 trailing 100 games avg -157.011
# episode  357 score -30.59 trailing 100 games avg -156.244
# episode  358 score -9.52 trailing 100 games avg -154.906
# episode  359 score -55.68 trailing 100 games avg -154.328
# episode  360 score -26.30 trailing 100 games avg -153.190
# episode  361 score -42.32 trailing 100 games avg -148.973
# episode  362 score -51.61 trailing 100 games avg -147.074
# episode  363 score -48.36 trailing 100 games avg -144.270
# episode  364 score -79.72 trailing 100 games avg -143.623
# episode  365 score -223.55 trailing 100 games avg -144.405
# episode  366 score -93.96 trailing 100 games avg -144.033
# episode  367 score -67.70 trailing 100 games avg -143.127
# episode  368 score -99.68 trailing 100 games avg -142.786
# episode  369 score -33.50 trailing 100 games avg -141.127
# episode  370 score -84.46 trailing 100 games avg -139.040
# episode  371 score -87.83 trailing 100 games avg -138.004
# episode  372 score -20.60 trailing 100 games avg -136.446
# episode  373 score -20.46 trailing 100 games avg -134.276
# episode  374 score -35.61 trailing 100 games avg -131.561
# episode  375 score -56.65 trailing 100 games avg -130.143
# episode  376 score -49.53 trailing 100 games avg -128.906
# episode  377 score -45.93 trailing 100 games avg -126.746
# episode  378 score -9.79 trailing 100 games avg -125.221
# episode  379 score -77.07 trailing 100 games avg -123.591
# episode  380 score -78.31 trailing 100 games avg -122.035
# episode  381 score 5.00 trailing 100 games avg -120.174
# episode  382 score 186.03 trailing 100 games avg -116.366
# episode  383 score 119.26 trailing 100 games avg -114.670
# episode  384 score -57.38 trailing 100 games avg -115.560
# episode  385 score -90.60 trailing 100 games avg -114.531
# episode  386 score -39.78 trailing 100 games avg -112.525
# episode  387 score -90.04 trailing 100 games avg -110.795
# episode  388 score -103.82 trailing 100 games avg -113.779
# episode  389 score -82.11 trailing 100 games avg -116.394
# episode  390 score 2.10 trailing 100 games avg -115.142
# episode  391 score 4.44 trailing 100 games avg -112.708
# episode  392 score -78.73 trailing 100 games avg -110.132
# episode  393 score -41.69 trailing 100 games avg -107.087
# episode  394 score -75.02 trailing 100 games avg -107.382
# episode  395 score -62.08 trailing 100 games avg -106.647
# episode  396 score 8.30 trailing 100 games avg -105.190
# episode  397 score -245.53 trailing 100 games avg -105.766
# episode  398 score -142.58 trailing 100 games avg -104.522
# episode  399 score -70.88 trailing 100 games avg -103.755
# episode  400 score -17.37 trailing 100 games avg -101.166
# episode  401 score -73.93 trailing 100 games avg -100.055
# episode  402 score -68.92 trailing 100 games avg -98.516
# episode  520 score 17.25 trailing 100 games avg -45.236
# episode  521 score -52.41 trailing 100 games avg -45.662
# episode  522 score -162.71 trailing 100 games avg -46.762
# episode  523 score 214.23 trailing 100 games avg -44.768
# episode  524 score -204.34 trailing 100 games avg -46.556
# episode  525 score 76.36 trailing 100 games avg -45.136
# episode  526 score 38.31 trailing 100 games avg -44.423
# episode  527 score -85.44 trailing 100 games avg -44.063
# episode  528 score 173.00 trailing 100 games avg -41.975
# episode  529 score -144.16 trailing 100 games avg -43.232
# episode  530 score -68.91 trailing 100 games avg -43.331
# episode  531 score -63.65 trailing 100 games avg -43.687
# episode  532 score -41.15 trailing 100 games avg -44.133
# episode  533 score 49.07 trailing 100 games avg -41.375
# episode  534 score -22.76 trailing 100 games avg -40.017
# episode  535 score -40.41 trailing 100 games avg -37.930
# episode  536 score -122.35 trailing 100 games avg -38.304
# episode  537 score 255.20 trailing 100 games avg -35.369
# episode  538 score -32.99 trailing 100 games avg -34.624
# episode  539 score 144.85 trailing 100 games avg -33.125
# episode  540 score -146.46 trailing 100 games avg -32.654
# episode  541 score -24.88 trailing 100 games avg -32.744
# episode  542 score -69.45 trailing 100 games avg -33.046
# episode  543 score -20.94 trailing 100 games avg -32.815
# episode  544 score -38.47 trailing 100 games avg -32.765
# episode  545 score 20.09 trailing 100 games avg -32.196
# episode  546 score 1.10 trailing 100 games avg -31.967
# episode  547 score 18.65 trailing 100 games avg -29.493
# episode  548 score 23.03 trailing 100 games avg -28.537
# episode  549 score -44.66 trailing 100 games avg -30.373
# episode  550 score -160.99 trailing 100 games avg -31.567
# episode  551 score -185.85 trailing 100 games avg -30.433
# episode  552 score 15.64 trailing 100 games avg -30.249
# episode  553 score -51.70 trailing 100 games avg -30.596
# episode  554 score -138.88 trailing 100 games avg -31.810
# episode  555 score -26.45 trailing 100 games avg -31.308
# episode  556 score -82.00 trailing 100 games avg -32.029
# episode  557 score -34.83 trailing 100 games avg -32.400
# episode  558 score -79.48 trailing 100 games avg -32.936
# episode  559 score -16.62 trailing 100 games avg -32.984
# episode  560 score 166.76 trailing 100 games avg -30.831
# episode  561 score -95.97 trailing 100 games avg -31.681
# episode  562 score -38.88 trailing 100 games avg -31.894
# episode  563 score -14.34 trailing 100 games avg -31.687
# episode  564 score 224.16 trailing 100 games avg -29.123
# episode  565 score -32.76 trailing 100 games avg -29.269
# episode  566 score -44.40 trailing 100 games avg -29.508
# episode  567 score -9.11 trailing 100 games avg -29.336
# episode  568 score -22.22 trailing 100 games avg -29.269
# episode  569 score -5.78 trailing 100 games avg -28.870
# episode  570 score 128.20 trailing 100 games avg -26.751
# episode  571 score -4.61 trailing 100 games avg -26.591
# episode  572 score -12.47 trailing 100 games avg -28.662
# episode  573 score -78.96 trailing 100 games avg -28.652
# episode  574 score -90.93 trailing 100 games avg -28.182
# episode  575 score -117.71 trailing 100 games avg -29.376
# episode  576 score -3.40 trailing 100 games avg -28.868
# episode  577 score -22.87 trailing 100 games avg -28.636
# episode  578 score -70.68 trailing 100 games avg -27.392
# episode  579 score -104.29 trailing 100 games avg -27.840
# episode  580 score 143.88 trailing 100 games avg -25.158
# episode  581 score 236.51 trailing 100 games avg -20.741
# episode  582 score -73.65 trailing 100 games avg -21.007
# episode  583 score -230.16 trailing 100 games avg -22.761
# episode  584 score -183.37 trailing 100 games avg -23.888
# episode  585 score -25.62 trailing 100 games avg -23.578
# episode  586 score -165.52 trailing 100 games avg -24.915
# episode  587 score -25.51 trailing 100 games avg -24.443
# episode  588 score -206.07 trailing 100 games avg -26.484
# episode  589 score -22.81 trailing 100 games avg -25.782
# episode  590 score 125.65 trailing 100 games avg -24.358
# episode  591 score 162.74 trailing 100 games avg -22.316
# episode  592 score 148.08 trailing 100 games avg -20.395
# episode  593 score -18.06 trailing 100 games avg -20.533
# episode  594 score -8.97 trailing 100 games avg -22.418
# episode  595 score 15.73 trailing 100 games avg -21.862
# episode  596 score -38.38 trailing 100 games avg -22.130
# episode  597 score -167.82 trailing 100 games avg -23.852
# episode  598 score -190.94 trailing 100 games avg -25.704
# episode  599 score 155.02 trailing 100 games avg -22.818
# episode  600 score 19.95 trailing 100 games avg -22.498
# episode  601 score -70.31 trailing 100 games avg -23.151
# episode  602 score -140.79 trailing 100 games avg -22.394
# episode  603 score -43.58 trailing 100 games avg -22.132
# episode  604 score -16.14 trailing 100 games avg -21.212
# episode  605 score 15.81 trailing 100 games avg -21.105
# episode  606 score -166.61 trailing 100 games avg -20.624
# episode  607 score 203.25 trailing 100 games avg -18.290
# episode  608 score 7.08 trailing 100 games avg -18.214
# episode  609 score 219.12 trailing 100 games avg -15.283
# episode  610 score -125.37 trailing 100 games avg -16.145
# episode  611 score -53.60 trailing 100 games avg -16.434
# episode  612 score -155.11 trailing 100 games avg -18.198
# episode  613 score 164.76 trailing 100 games avg -18.613
# episode  614 score 6.83 trailing 100 games avg -18.612
# episode  615 score -22.84 trailing 100 games avg -20.812
# episode  616 score 274.77 trailing 100 games avg -17.652
# episode  617 score -100.78 trailing 100 games avg -16.981
# episode  618 score -228.16 trailing 100 games avg -18.406
# episode  619 score 137.37 trailing 100 games avg -18.100
# episode  620 score 253.15 trailing 100 games avg -15.741
# episode  621 score 189.63 trailing 100 games avg -13.321
# episode  622 score -196.82 trailing 100 games avg -13.662
# episode  623 score -252.01 trailing 100 games avg -18.324
# episode  624 score -100.08 trailing 100 games avg -17.282
# episode  625 score -33.37 trailing 100 games avg -18.379
# episode  626 score 200.00 trailing 100 games avg -16.762
# episode  627 score -139.84 trailing 100 games avg -17.306
# episode  628 score -92.70 trailing 100 games avg -19.963
# episode  629 score -104.80 trailing 100 games avg -19.570
# episode  630 score -155.74 trailing 100 games avg -20.438
# episode  631 score -42.53 trailing 100 games avg -20.227
# episode  632 score 170.73 trailing 100 games avg -18.108
# episode  633 score 255.82 trailing 100 games avg -16.040
# episode  634 score -51.80 trailing 100 games avg -16.331
# episode  635 score -183.45 trailing 100 games avg -17.761
# episode  753 score 248.34 trailing 100 games avg -63.282
# episode  754 score 255.98 trailing 100 games avg -59.879
# episode  755 score 200.73 trailing 100 games avg -57.078
# episode  756 score 126.70 trailing 100 games avg -54.404
# episode  757 score 218.66 trailing 100 games avg -49.764
# episode  758 score -252.56 trailing 100 games avg -51.882
# episode  759 score 219.73 trailing 100 games avg -47.519
# episode  760 score 226.04 trailing 100 games avg -44.085
# episode  761 score 235.52 trailing 100 games avg -41.703
# episode  762 score -321.02 trailing 100 games avg -44.162
# episode  763 score 147.66 trailing 100 games avg -41.824
# episode  764 score 207.04 trailing 100 games avg -41.248
# episode  765 score -113.36 trailing 100 games avg -40.680
# episode  766 score -70.01 trailing 100 games avg -39.543
# episode  767 score 215.17 trailing 100 games avg -36.406
# episode  768 score -92.06 trailing 100 games avg -36.723
# episode  769 score -5.11 trailing 100 games avg -34.908
# episode  770 score -112.56 trailing 100 games avg -35.858
# episode  771 score -83.16 trailing 100 games avg -35.918
# episode  772 score -119.76 trailing 100 games avg -35.843
# episode  773 score -12.86 trailing 100 games avg -35.298
# episode  774 score -145.45 trailing 100 games avg -36.361
# episode  775 score -99.04 trailing 100 games avg -38.043
# episode  776 score -84.40 trailing 100 games avg -41.077
# episode  777 score -132.84 trailing 100 games avg -43.885
# episode  778 score -20.00 trailing 100 games avg -44.806
# episode  779 score -74.09 trailing 100 games avg -43.009
# episode  780 score 179.96 trailing 100 games avg -38.668
# episode  781 score -60.66 trailing 100 games avg -40.709
# episode  782 score -42.23 trailing 100 games avg -39.976
# episode  783 score 148.39 trailing 100 games avg -40.892
# episode  784 score -9.61 trailing 100 games avg -39.895
# episode  785 score -102.17 trailing 100 games avg -40.106
# episode  786 score -235.37 trailing 100 games avg -44.597
# episode  787 score -192.99 trailing 100 games avg -48.594
# episode  788 score -206.66 trailing 100 games avg -49.094
# episode  789 score -156.14 trailing 100 games avg -50.125
# episode  790 score -214.32 trailing 100 games avg -52.154
# episode  791 score -26.15 trailing 100 games avg -48.460
# episode  792 score 1.12 trailing 100 games avg -48.147
# episode  793 score -1.40 trailing 100 games avg -47.046
# episode  794 score -13.06 trailing 100 games avg -47.331
# episode  795 score -116.09 trailing 100 games avg -48.345
# episode  796 score 153.93 trailing 100 games avg -44.334
# episode  797 score 171.21 trailing 100 games avg -40.839
# episode  798 score 215.01 trailing 100 games avg -37.341
# episode  799 score 147.72 trailing 100 games avg -35.147
# episode  800 score -45.31 trailing 100 games avg -37.295
# episode  801 score -144.90 trailing 100 games avg -38.238
# episode  802 score 182.56 trailing 100 games avg -35.932
# episode  803 score 167.64 trailing 100 games avg -34.000
# episode  804 score 230.03 trailing 100 games avg -33.408
# episode  805 score 214.16 trailing 100 games avg -33.334
# episode  806 score 247.65 trailing 100 games avg -29.819
# episode  807 score -215.10 trailing 100 games avg -31.675
# episode  808 score -92.47 trailing 100 games avg -31.295
# episode  809 score 185.26 trailing 100 games avg -28.118
# episode  810 score 247.33 trailing 100 games avg -24.604
# episode  811 score 187.37 trailing 100 games avg -21.637
# episode  812 score -211.49 trailing 100 games avg -23.305
# episode  813 score 199.46 trailing 100 games avg -21.229
# episode  814 score 171.33 trailing 100 games avg -19.038
# episode  815 score 232.93 trailing 100 games avg -15.692
# episode  816 score 191.62 trailing 100 games avg -11.803
# episode  817 score 18.09 trailing 100 games avg -8.281
# episode  818 score 208.82 trailing 100 games avg -4.297
# episode  819 score 221.42 trailing 100 games avg 0.322
# episode  820 score 178.54 trailing 100 games avg 4.715
# episode  821 score 182.89 trailing 100 games avg 9.302
# episode  822 score 187.23 trailing 100 games avg 13.045
# episode  823 score 166.46 trailing 100 games avg 16.028
# episode  824 score 217.57 trailing 100 games avg 19.230
# episode  825 score 176.74 trailing 100 games avg 23.284
# episode  826 score -248.57 trailing 100 games avg 22.048
# episode  827 score 185.24 trailing 100 games avg 24.766
# episode  828 score 220.38 trailing 100 games avg 28.357
# episode  829 score 208.05 trailing 100 games avg 27.878
# episode  830 score 207.03 trailing 100 games avg 31.232
# episode  831 score 252.25 trailing 100 games avg 31.780
# episode  832 score 235.86 trailing 100 games avg 35.760
# episode  833 score 246.69 trailing 100 games avg 38.863
# episode  834 score 249.77 trailing 100 games avg 41.176
# episode  835 score 200.71 trailing 100 games avg 44.562
# episode  836 score 188.16 trailing 100 games avg 47.850
# episode  837 score -3.32 trailing 100 games avg 48.492
# episode  838 score 89.20 trailing 100 games avg 50.348
# episode  839 score 266.55 trailing 100 games avg 53.939
# episode  840 score 208.49 trailing 100 games avg 57.057
# episode  841 score 217.10 trailing 100 games avg 61.648
# episode  842 score -8.49 trailing 100 games avg 63.310
# episode  843 score 186.83 trailing 100 games avg 65.884
# episode  844 score 256.17 trailing 100 games avg 66.180
# episode  845 score 230.82 trailing 100 games avg 69.325
# episode  846 score 226.09 trailing 100 games avg 72.458
# episode  847 score 0.57 trailing 100 games avg 70.458
# episode  848 score 198.98 trailing 100 games avg 74.357
# episode  849 score 190.92 trailing 100 games avg 75.184
# episode  850 score -185.35 trailing 100 games avg 74.579
# episode  851 score -105.73 trailing 100 games avg 73.998
# episode  852 score -274.56 trailing 100 games avg 69.494
# episode  853 score 243.14 trailing 100 games avg 69.442
# episode  854 score 208.83 trailing 100 games avg 68.971
# episode  855 score 235.01 trailing 100 games avg 69.313
# episode  856 score 163.40 trailing 100 games avg 69.681
# episode  857 score 234.43 trailing 100 games avg 69.838
# episode  858 score 158.12 trailing 100 games avg 73.945
# episode  859 score 213.97 trailing 100 games avg 73.887
# episode  860 score 207.74 trailing 100 games avg 73.704
# episode  861 score 248.91 trailing 100 games avg 73.838
# episode  862 score 209.35 trailing 100 games avg 79.142
# episode  863 score 231.65 trailing 100 games avg 79.982
# episode  864 score 196.60 trailing 100 games avg 79.878
# episode  865 score -242.98 trailing 100 games avg 78.582
# episode  866 score -103.87 trailing 100 games avg 78.243
# episode  867 score -60.05 trailing 100 games avg 75.491
# episode  868 score -157.64 trailing 100 games avg 74.835
