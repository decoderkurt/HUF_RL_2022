# %% [markdown]
# <a href="https://colab.research.google.com/github/decoderkurt/HUF_RL_2022/blob/main/19/rl-baselines-zoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RL Baselines3 Zoo: Training in Colab
#
#
#
# Github Repo: [https://github.com/DLR-RM/rl-baselines3-zoo](https://github.com/DLR-RM/rl-baselines3-zoo)
#
# Stable-Baselines3 Repo: [https://github.com/DLR-RM/rl-baselines3-zoo](https://github.com/DLR-RM/stable-baselines3)
#
#
# # Install Dependencies

# %%
# !apt-get install swig cmake ffmpeg freeglut3-dev xvfb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# freeglut3-dev is already the newest version (2.8.1-3).
# swig is already the newest version (3.0.12-1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# xvfb is already the newest version (2:1.19.6-1ubuntu4.10).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %% [markdown]
# ## Clone RL Baselines3 Zoo Repo

# %%
# !git clone --recursive https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# fatal: destination path 'rl-baselines3-zoo' already exists and is not an empty directory.

# %%
# %cd /content/rl-baselines3-zoo/
# Out:
# /content/rl-baselines3-zoo

# %% [markdown]
# ### Install pip dependencies

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gym<0.20,>=0.17 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (0.17.3)
# Requirement already satisfied: stable-baselines3[docs,extra,tests]>=1.3.1a8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.3.1a9)
# Requirement already satisfied: sb3-contrib>=1.3.1a7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.3.1a7)
# Requirement already satisfied: box2d-py==2.3.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (2.3.8)
# Requirement already satisfied: pybullet in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: gym-minigrid in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: pytablewriter in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (0.64.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (0.11.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (6.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (1.6.0)
# Requirement already satisfied: atari-py==0.2.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 14)) (0.2.6)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (4.4.1)
# Requirement already satisfied: panda-gym==1.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 16)) (1.1.1)
# Requirement already satisfied: rliable>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 17)) (1.0.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from atari-py==0.2.6->-r requirements.txt (line 14)) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from atari-py==0.2.6->-r requirements.txt (line 14)) (1.15.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym<0.20,>=0.17->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym<0.20,>=0.17->-r requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.1.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.10.0+cu111)
# Requirement already satisfied: absl-py>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rliable>=1.0.5->-r requirements.txt (line 17)) (0.12.0)
# Requirement already satisfied: arch>=4.19 in /usr/local/lib/python3.7/dist-packages (from rliable>=1.0.5->-r requirements.txt (line 17)) (5.1.0)
# Requirement already satisfied: property-cached>=1.6.4 in /usr/local/lib/python3.7/dist-packages (from arch>=4.19->rliable>=1.0.5->-r requirements.txt (line 17)) (1.6.4)
# Requirement already satisfied: statsmodels>=0.11 in /usr/local/lib/python3.7/dist-packages (from arch>=4.19->rliable>=1.0.5->-r requirements.txt (line 17)) (0.13.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<0.20,>=0.17->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (5.4.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (4.1.2.30)
# Requirement already satisfied: flake8-bugbear in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (22.1.11)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (4.3.1)
# Requirement already satisfied: pytest-env in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: flake8>=3.8 in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (4.0.1)
# Requirement already satisfied: isort>=5.0 in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (5.10.1)
# Requirement already satisfied: pytest-xdist in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.27.0)
# Requirement already satisfied: black in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (21.12b0)
# Requirement already satisfied: pytest-cov in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: pytype in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2022.1.13)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: sphinx-autodoc-typehints in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.15.2)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (4.3.2)
# Requirement already satisfied: sphinxcontrib.spelling in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (7.3.2)
# Requirement already satisfied: sphinx-autobuild in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2021.3.14)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: importlib-metadata<4.3 in /usr/local/lib/python3.7/dist-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3->flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3->flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.10.0.2)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11->arch>=4.19->rliable>=1.0.5->-r requirements.txt (line 17)) (0.5.2)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.43.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize->-r requirements.txt (line 7)) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize->-r requirements.txt (line 7)) (21.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->scikit-optimize->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 8)) (4.62.3)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 8)) (1.4.29)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 8)) (0.8.2)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 8)) (21.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 8)) (6.6.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 8)) (1.7.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna->-r requirements.txt (line 8)) (3.0.6)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna->-r requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from pytablewriter->-r requirements.txt (line 9)) (0.1.1)
# Requirement already satisfied: pathvalidate<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter->-r requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: DataProperty<2,>=0.54.2 in /usr/local/lib/python3.7/dist-packages (from pytablewriter->-r requirements.txt (line 9)) (0.54.2)
# Requirement already satisfied: tabledata<2,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: typepy[datetime]<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->-r requirements.txt (line 15)) (1.3.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna->-r requirements.txt (line 8)) (1.1.6)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna->-r requirements.txt (line 8)) (5.4.0)
# Requirement already satisfied: typed-ast>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from black->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: click>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from black->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.7/dist-packages (from black->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from black->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.2.3)
# Requirement already satisfied: pathspec<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from black->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from black->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->-r requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->-r requirements.txt (line 8)) (5.8.0)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->-r requirements.txt (line 8)) (2.3.3)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->-r requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements.txt (line 8)) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements.txt (line 8)) (21.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna->-r requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.11.0)
# Requirement already satisfied: pluggy>=0.7 in /usr/local/lib/python3.7/dist-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (8.12.0)
# Requirement already satisfied: coverage>=4.4 in /usr/local/lib/python3.7/dist-packages (from pytest-cov->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (6.2)
# Requirement already satisfied: execnet>=1.1 in /usr/local/lib/python3.7/dist-packages (from pytest-xdist->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: pytest-forked in /usr/local/lib/python3.7/dist-packages (from pytest-xdist->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: ninja>=1.10.0.post2 in /usr/local/lib/python3.7/dist-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.10.2.3)
# Requirement already satisfied: importlab>=0.7 in /usr/local/lib/python3.7/dist-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.7)
# Requirement already satisfied: libcst in /usr/local/lib/python3.7/dist-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.8.9)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: networkx>=2 in /usr/local/lib/python3.7/dist-packages (from importlab>=0.7->pytype->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from libcst->pytype->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.11.3)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.0.2)
# Requirement already satisfied: docutils<0.18,>=0.14 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.17.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.0.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.7.12)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.9.1)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (1.1.5)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sphinx-autobuild->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (0.4.4)
# Requirement already satisfied: livereload in /usr/local/lib/python3.7/dist-packages (from sphinx-autobuild->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from livereload->sphinx-autobuild->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: PyEnchant>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib.spelling->stable-baselines3[docs,extra,tests]>=1.3.1a8->-r requirements.txt (line 2)) (3.2.2)

# %% [markdown]
# ## Train an RL Agent
#
#
# The train agent can be found in the `logs/` folder.
#
# Here we will train A2C on CartPole-v1 environment for 100 000 steps.
#
#
# To train it on Pong (Atari), you just have to pass `--env PongNoFrameskip-v4`
#
# Note: You need to update `hyperparams/algo.yml` to support new environments. You can access it in the side panel of Google Colab. (see https://stackoverflow.com/questions/46986398/import-data-into-google-colaboratory)

# %%
# !python train.py --algo a2c --env CartPole-v1 --n-timesteps 10
# Out:
# ========== CartPole-v1 ==========
# Seed: 3430206127
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('ent_coef', 0.0),
#              ('n_envs', 8),
#              ('n_timesteps', 500000.0),
#              ('policy', 'MlpPolicy')])
# Using 8 environments
# Overwriting n_timesteps with n=10
# Creating test environment
# Using cpu device
# Log path: logs/a2c/CartPole-v1_1
# Saving to logs/a2c/CartPole-v1_1

# %% [markdown]
# #### Evaluate trained agent
#
#
# You can remove the `--folder logs/` to evaluate pretrained agent.

# %%
# !python enjoy.py --algo a2c --env CartPole-v1 --no-render --n-timesteps 5000 --folder logs/
# Out:
# Loading latest experiment, id=1
# Loading logs/a2c/CartPole-v1_1/CartPole-v1.zip
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 32.00
# Episode Length 32
# Episode Reward: 31.00
# Episode Length 31
# Episode Reward: 31.00
# Episode Length 31
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 32.00
# Episode Length 32
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 17.00
# Episode Length 17
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 29.00
# Episode Length 29
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 18.00
# Episode Length 18
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 32.00
# Episode Length 32
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 32.00
# Episode Length 32
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 18.00
# Episode Length 18
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 34.00
# Episode Length 34
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 35.00
# Episode Length 35
# Episode Reward: 32.00
# Episode Length 32
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 33.00
# Episode Length 33
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 18.00
# Episode Length 18
# Episode Reward: 35.00
# Episode Length 35
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 33.00
# Episode Length 33
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 33.00
# Episode Length 33
# Episode Reward: 29.00
# Episode Length 29
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 33.00
# Episode Length 33
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 21.00
# Episode Length 21
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 30.00
# Episode Length 30
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 17.00
# Episode Length 17
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 17.00
# Episode Length 17
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 20.00
# Episode Length 20
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 36.00
# Episode Length 36
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 17.00
# Episode Length 17
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 37.00
# Episode Length 37
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 17.00
# Episode Length 17
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 9.00
# Episode Length 9
# Episode Reward: 17.00
# Episode Length 17
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 33.00
# Episode Length 33
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 31.00
# Episode Length 31
# Episode Reward: 29.00
# Episode Length 29
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 35.00
# Episode Length 35
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 31.00
# Episode Length 31
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 30.00
# Episode Length 30
# Episode Reward: 33.00
# Episode Length 33
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 14.00
# Episode Length 14
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 10.00
# Episode Length 10
# Episode Reward: 15.00
# Episode Length 15
# Episode Reward: 16.00
# Episode Length 16
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 13.00
# Episode Length 13
# Episode Reward: 29.00
# Episode Length 29
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 20.00
# Episode Length 20
# Episode Reward: 11.00
# Episode Length 11
# Episode Reward: 12.00
# Episode Length 12
# Episode Reward: 35.00
# Episode Length 35
# 357 Episodes
# Mean reward: 14.00 +/- 5.75
# Mean episode length: 14.00 +/- 5.75

# %% [markdown]
# #### Tune Hyperparameters
#
# We use [Optuna](https://optuna.org/) for optimizing the hyperparameters.
#
# Tune the hyperparameters for PPO, using a tpe sampler and median pruner, 2 parallels jobs,
# with a budget of 1000 trials and a maximum of 50000 steps

# %%
# !python train.py --algo ppo --env MountainCar-v0 -n 50 -optimize --n-trials 1 --n-jobs 2 --sampler tpe --pruner median
# Out:
# ========== MountainCar-v0 ==========
# Seed: 2632319663
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('ent_coef', 0.0),
#              ('gae_lambda', 0.98),
#              ('gamma', 0.99),
#              ('n_envs', 16),
#              ('n_epochs', 4),
#              ('n_steps', 16),
#              ('n_timesteps', 1000000.0),
#              ('normalize', True),
#              ('policy', 'MlpPolicy')])
# Using 16 environments
# Overwriting n_timesteps with n=50
# Normalization activated: {'gamma': 0.99}
# Optimizing hyperparameters
# Sampler: tpe - Pruner: median
# [I 2022-01-18 00:46:41,638] A new study created in memory with name: no-name-32e2ee8b-3225-45b6-82c8-6dcfcb061db1
# /usr/local/lib/python3.7/dist-packages/optuna/study/study.py:397: FutureWarning:
#
# `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#
# Normalization activated: {'gamma': 0.99}
# Normalization activated: {'gamma': 0.99, 'norm_reward': False}
# [I 2022-01-18 00:46:48,479] Trial 0 finished with value: -200.0 and parameters: {'batch_size': 256, 'n_steps': 8, 'gamma': 0.9999, 'learning_rate': 0.3270842923094914, 'ent_coef': 1.581420984681729e-07, 'clip_range': 0.4, 'n_epochs': 10, 'gae_lambda': 0.92, 'max_grad_norm': 5, 'vf_coef': 0.526214719917527, 'net_arch': 'small', 'activation_fn': 'relu'}. Best is trial 0 with value: -200.0.
# Number of finished trials:  1
# Best trial:
# Value:  -200.0
# Params:
#     batch_size: 256
#     n_steps: 8
#     gamma: 0.9999
#     learning_rate: 0.3270842923094914
#     ent_coef: 1.581420984681729e-07
#     clip_range: 0.4
#     n_epochs: 10
#     gae_lambda: 0.92
#     max_grad_norm: 5
#     vf_coef: 0.526214719917527
#     net_arch: small
#     activation_fn: relu
# Writing report to logs/ppo/report_MountainCar-v0_1-trials-50-tpe-median_1642466808

# %% [markdown]
# ### Record  a Video

# %%
# Set up display; otherwise rendering will fail
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

# %%
# !python -m utils.record_video --algo a2c --env CartPole-v1 --exp-id 0 -f logs/ -n 1000
# Out:
# Loading latest experiment, id=1
# Saving video to /content/rl-baselines3-zoo/logs/a2c/CartPole-v1_1/videos/final-model-a2c-CartPole-v1-step-0-to-step-1000.mp4

# %% [markdown]
# ### Display the video

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay

def show_videos(video_path='', prefix=''):
  """
  Taken from https://github.com/eleurent/highway-env

  :param video_path: (str) Path to the folder containing videos
  :param prefix: (str) Filter the video, showing only the only starting with this prefix
  """
  html = []
  for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
      video_b64 = base64.b64encode(mp4.read_bytes())
      html.append('''<video alt="{}" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>'''.format(mp4, video_b64.decode('ascii')))
  ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
show_videos(video_path='logs/videos/', prefix='a2c')

# %% [markdown]
# ### Continue Training
#
# Here, we will continue training of the previous model

# %%
# !python train.py --algo a2c --env CartPole-v1 --n-timesteps 50000 -i logs/a2c/CartPole-v1_1/CartPole-v1.zip
# Out:
# Traceback (most recent call last):
#   File "train.py", line 15, in <module>

# %%
# !python enjoy.py --algo a2c --env CartPole-v1 --no-render --n-timesteps 1000 --folder logs/
